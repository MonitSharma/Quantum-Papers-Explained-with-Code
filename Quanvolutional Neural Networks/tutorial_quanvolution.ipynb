# %%
# This cell is added by sphinx-gallery
# It can be customized to whatever you like
# %matplotlib inline

# %% [markdown]
# Quanvolutional Neural Networks {#quanvolution}
# ==============================
#
#
# Introduction
# ------------
#
# ### Classical convolution
#
# The *convolutional neural network* (CNN) is a standard model in
# classical machine learning which is particularly suitable for processing
# images. The model is based on the idea of a *convolution layer* where,
# instead of processing the full input data with a global function, a
# local convolution is applied.
#
# If the input is an image, small local regions are sequentially processed
# with the same kernel. The results obtained for each region are usually
# associated to different channels of a single output pixel. The union of
# all the output pixels produces a new image-like object, which can be
# further processed by additional layers.
#
# ### Quantum convolution
#
# One can extend the same idea also to the context of quantum variational
# circuits. A possible approach is given by the following procedure which
# is very similar to the one used in Ref. \[1\]. The scheme is also
# represented in the figure at the top of this tutorial.
#
# 1.  A small region of the input image, in our example a $2 \times 2$
#     square, is embedded into a quantum circuit. In this demo, this is
#     achieved with parametrized rotations applied to the qubits
#     initialized in the ground state.
# 2.  A quantum computation, associated to a unitary $U$, is performed on
#     the system. The unitary could be generated by a variational quantum
#     circuit or, more simply, by a random circuit as proposed in Ref.
#     \[1\].
# 3.  The quantum system is finally measured, obtaining a list of
#     classical expectation values. The measurement results could also be
#     classically post-processed as proposed in Ref. \[1\] but, for
#     simplicity, in this demo we directly use the raw expectation values.
# 4.  Analogously to a classical convolution layer, each expectation value
#     is mapped to a different channel of a single output pixel.
# 5.  Iterating the same procedure over different regions, one can scan
#     the full input image, producing an output object which will be
#     structured as a multi-channel image.
# 6.  The quantum convolution can be followed by further quantum layers or
#     by classical layers.
#
# The main difference with respect to a classical convolution is that a
# quantum circuit can generate highly complex kernels whose computation
# could be, at least in principle, classically intractable.

# %%
# !pip install tensorflow

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# Setting of the main hyper-parameters of the model
# =================================================

# %%
n_epochs = 100   # Number of optimization epochs
n_layers = 3    # Number of random layers
n_train = 100    # Size of the train dataset
n_test = 20     # Size of the test dataset

SAVE_PATH = "quanvolution/" # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(135)           # Seed for NumPy random number generator
tf.random.set_seed(135)       # Seed for TensorFlow random number generator

# %% [markdown]
# Loading of the MNIST dataset
# ============================
#
# We import the MNIST dataset from *Keras*. To speedup the evaluation of
# this demo we use only a small number of training and test images.
# Obviously, better results are achievable when using the full dataset.

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# Quantum circuit as a convolution kernel
# =======================================
#
# We follow the scheme described in the introduction and represented in
# the figure at the top of this demo.
#
# We initialize a PennyLane `default.qubit` device, simulating a system of
# $4$ qubits. The associated `qnode` represents the quantum circuit
# consisting of:
#
# 1.  an embedding layer of local $R_y$ rotations (with angles scaled by a
#     factor of $\pi$);
# 2.  a random circuit of `n_layers`;
# 3.  a final measurement in the computational basis, estimating $4$
#     expectation values.

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev, interface="autograd")
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %% [markdown]
# The next function defines the convolution scheme:
#
# 1.  the image is divided into squares of $2 \times 2$ pixels;
# 2.  each square is processed by the quantum circuit;
# 3.  the $4$ expectation values are mapped into $4$ different channels of
#     a single output pixel.
#
# ::: {.note}
# ::: {.title}
# Note
# :::
#
# This process halves the resolution of the input image. In the standard
# language of CNN, this would correspond to a convolution with a
# $2 \times 2$ *kernel* and a *stride* equal to $2$.
# :::

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# Quantum pre-processing of the dataset
# =====================================
#
# Since we are not going to train the quantum convolution layer, it is
# more efficient to apply it as a \"pre-processing\" layer to all the
# images of our dataset. Later an entirely classical model will be
# directly trained and tested on the pre-processed dataset, avoiding
# unnecessary repetitions of quantum computations.
#
# The pre-processed images will be saved in the folder `SAVE_PATH`. Once
# saved, they can be directly loaded by setting `PREPROCESS = False`,
# otherwise the quantum convolution is evaluated at each run of the code.

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 100/100
# Quantum pre-processing of test images:
# 20/20

# %% [markdown]
# Let us visualize the effect of the quantum convolution layer on a batch
# of samples:

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# Below each input image, the $4$ output channels generated by the quantum
# convolution are visualized in gray scale.
#
# One can clearly notice the downsampling of the resolution and some local
# distortion introduced by the quantum kernel. On the other hand the
# global shape of the image is preserved, as expected for a convolution
# layer.

# %% [markdown]
# Hybrid quantum-classical model
# ==============================
#
# After the application of the quantum convolution layer we feed the
# resulting features into a classical neural network that will be trained
# to classify the $10$ different digits of the MNIST dataset.
#
# We use a very simple model: just a fully connected layer with 10 output
# nodes with a final *softmax* activation function.
#
# The model is compiled with a *stochastic-gradient-descent* optimizer,
# and a *cross-entropy* loss function.

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# Training
# ========
#
# We first initialize an instance of the model, then we train and validate
# it with the dataset that has been already pre-processed by a quantum
# convolution.

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/100
# 25/25 - 0s - loss: 2.4281 - accuracy: 0.1700 - val_loss: 2.1504 - val_accuracy: 0.3000 - 269ms/epoch - 11ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 2.0221 - accuracy: 0.4000 - val_loss: 1.9892 - val_accuracy: 0.5000 - 34ms/epoch - 1ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 1.7343 - accuracy: 0.6300 - val_loss: 1.8520 - val_accuracy: 0.5000 - 34ms/epoch - 1ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 1.4796 - accuracy: 0.6600 - val_loss: 1.7375 - val_accuracy: 0.5000 - 33ms/epoch - 1ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 1.2574 - accuracy: 0.8200 - val_loss: 1.6308 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 1.0829 - accuracy: 0.9100 - val_loss: 1.5767 - val_accuracy: 0.5500 - 32ms/epoch - 1ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.9416 - accuracy: 0.9100 - val_loss: 1.5087 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 0.8167 - accuracy: 0.9500 - val_loss: 1.4702 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 0.7196 - accuracy: 0.9800 - val_loss: 1.4087 - val_accuracy: 0.5500 - 33ms/epoch - 1ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 0.6303 - accuracy: 0.9900 - val_loss: 1.3801 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 0.5485 - accuracy: 0.9800 - val_loss: 1.3580 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 0.4917 - accuracy: 1.0000 - val_loss: 1.3468 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 0.4321 - accuracy: 1.0000 - val_loss: 1.2964 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 0.3979 - accuracy: 1.0000 - val_loss: 1.2798 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 0.3506 - accuracy: 1.0000 - val_loss: 1.2835 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 0.3247 - accuracy: 1.0000 - val_loss: 1.2592 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 0.2917 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 0.2656 - accuracy: 1.0000 - val_loss: 1.2520 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 0.2488 - accuracy: 1.0000 - val_loss: 1.2459 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 0.2244 - accuracy: 1.0000 - val_loss: 1.2302 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 0.2055 - accuracy: 1.0000 - val_loss: 1.2303 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 0.1896 - accuracy: 1.0000 - val_loss: 1.2269 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 0.1774 - accuracy: 1.0000 - val_loss: 1.2162 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 0.1648 - accuracy: 1.0000 - val_loss: 1.2078 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 0.1564 - accuracy: 1.0000 - val_loss: 1.2323 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 0.1437 - accuracy: 1.0000 - val_loss: 1.2102 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 0.1358 - accuracy: 1.0000 - val_loss: 1.2276 - val_accuracy: 0.6000 - 34ms/epoch - 1ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 0.1271 - accuracy: 1.0000 - val_loss: 1.2110 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 0.1214 - accuracy: 1.0000 - val_loss: 1.2178 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 0.1123 - accuracy: 1.0000 - val_loss: 1.1983 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 0.1066 - accuracy: 1.0000 - val_loss: 1.2070 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 0.0999 - accuracy: 1.0000 - val_loss: 1.2266 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 0.0953 - accuracy: 1.0000 - val_loss: 1.2238 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 0.0911 - accuracy: 1.0000 - val_loss: 1.2265 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 0.0861 - accuracy: 1.0000 - val_loss: 1.2029 - val_accuracy: 0.6500 - 32ms/epoch - 1ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.2283 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 0.0786 - accuracy: 1.0000 - val_loss: 1.2199 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.2268 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 0.0720 - accuracy: 1.0000 - val_loss: 1.2203 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 40/100
# 25/25 - 0s - loss: 0.0683 - accuracy: 1.0000 - val_loss: 1.2279 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 0.0649 - accuracy: 1.0000 - val_loss: 1.2225 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 0.0631 - accuracy: 1.0000 - val_loss: 1.2380 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 0.0600 - accuracy: 1.0000 - val_loss: 1.2206 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 0.0578 - accuracy: 1.0000 - val_loss: 1.2381 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 0.0554 - accuracy: 1.0000 - val_loss: 1.2248 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 0.0539 - accuracy: 1.0000 - val_loss: 1.2387 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 1.2328 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 0.0494 - accuracy: 1.0000 - val_loss: 1.2386 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 0.0476 - accuracy: 1.0000 - val_loss: 1.2453 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 0.0459 - accuracy: 1.0000 - val_loss: 1.2353 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 0.0445 - accuracy: 1.0000 - val_loss: 1.2505 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 0.0430 - accuracy: 1.0000 - val_loss: 1.2487 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 0.0418 - accuracy: 1.0000 - val_loss: 1.2429 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 0.0388 - accuracy: 1.0000 - val_loss: 1.2525 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 1.2620 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 1.2619 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.2680 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 0.0343 - accuracy: 1.0000 - val_loss: 1.2614 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.2551 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.2771 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 0.0313 - accuracy: 1.0000 - val_loss: 1.2687 - val_accuracy: 0.6000 - 36ms/epoch - 1ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 0.0303 - accuracy: 1.0000 - val_loss: 1.2731 - val_accuracy: 0.6000 - 35ms/epoch - 1ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 1.2821 - val_accuracy: 0.6000 - 37ms/epoch - 1ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 1.2681 - val_accuracy: 0.6000 - 37ms/epoch - 1ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 1.2659 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.2847 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.2727 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.2900 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.2798 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 1.2953 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 1.2933 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.2803 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.2879 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 1.2947 - val_accuracy: 0.6000 - 34ms/epoch - 1ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.3038 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 0.0210 - accuracy: 1.0000 - val_loss: 1.2844 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.3050 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.2924 - val_accuracy: 0.6000 - 34ms/epoch - 1ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.3121 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.3050 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 1.3100 - val_accuracy: 0.6000 - 22ms/epoch - 871us/step
# Epoch 83/100
# 25/25 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 1.3017 - val_accuracy: 0.6000 - 43ms/epoch - 2ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 1.3024 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.3095 - val_accuracy: 0.6000 - 34ms/epoch - 1ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 0.0168 - accuracy: 1.0000 - val_loss: 1.3153 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 1.3043 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 1.3089 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.3201 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.3325 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 1.3130 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.3217 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.3211 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.3245 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.3315 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.3398 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.3253 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.3220 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.3381 - val_accuracy: 0.6000 - 32ms/epoch - 1ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.3348 - val_accuracy: 0.6000 - 31ms/epoch - 1ms/step

# %% [markdown]
# In order to compare the results achievable with and without the quantum
# convolution layer, we initialize also a \"classical\" instance of the
# model that will be directly trained and validated with the raw MNIST
# images (i.e., without quantum pre-processing).

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/100
# 25/25 - 0s - loss: 2.1808 - accuracy: 0.2300 - val_loss: 1.9853 - val_accuracy: 0.3000 - 254ms/epoch - 10ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 1.6160 - accuracy: 0.6700 - val_loss: 1.7530 - val_accuracy: 0.5000 - 35ms/epoch - 1ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 1.2347 - accuracy: 0.8500 - val_loss: 1.5585 - val_accuracy: 0.6000 - 33ms/epoch - 1ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 0.9646 - accuracy: 0.9200 - val_loss: 1.4184 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 0.7709 - accuracy: 0.9600 - val_loss: 1.3120 - val_accuracy: 0.7500 - 32ms/epoch - 1ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 0.6338 - accuracy: 0.9600 - val_loss: 1.2405 - val_accuracy: 0.7500 - 33ms/epoch - 1ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.5362 - accuracy: 0.9600 - val_loss: 1.1935 - val_accuracy: 0.7500 - 32ms/epoch - 1ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 0.4558 - accuracy: 0.9700 - val_loss: 1.1581 - val_accuracy: 0.7500 - 32ms/epoch - 1ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 0.3952 - accuracy: 0.9700 - val_loss: 1.1228 - val_accuracy: 0.7500 - 31ms/epoch - 1ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 0.3430 - accuracy: 0.9800 - val_loss: 1.0956 - val_accuracy: 0.7500 - 34ms/epoch - 1ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 0.3023 - accuracy: 0.9900 - val_loss: 1.0820 - val_accuracy: 0.7500 - 32ms/epoch - 1ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 0.2668 - accuracy: 1.0000 - val_loss: 1.0822 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 0.2394 - accuracy: 1.0000 - val_loss: 1.0801 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 0.2137 - accuracy: 1.0000 - val_loss: 1.0515 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 0.1934 - accuracy: 1.0000 - val_loss: 1.0572 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 0.1761 - accuracy: 1.0000 - val_loss: 1.0510 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 0.1605 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 0.1460 - accuracy: 1.0000 - val_loss: 1.0442 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 0.1356 - accuracy: 1.0000 - val_loss: 1.0507 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 0.1241 - accuracy: 1.0000 - val_loss: 1.0412 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 0.1151 - accuracy: 1.0000 - val_loss: 1.0413 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 0.1065 - accuracy: 1.0000 - val_loss: 1.0470 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 0.0995 - accuracy: 1.0000 - val_loss: 1.0512 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 0.0930 - accuracy: 1.0000 - val_loss: 1.0402 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 0.0870 - accuracy: 1.0000 - val_loss: 1.0510 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.0549 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1.0544 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 0.0724 - accuracy: 1.0000 - val_loss: 1.0490 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 0.0686 - accuracy: 1.0000 - val_loss: 1.0581 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 1.0574 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 0.0612 - accuracy: 1.0000 - val_loss: 1.0535 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 0.0580 - accuracy: 1.0000 - val_loss: 1.0600 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 0.0550 - accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 0.0526 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 1.0688 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 0.0478 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 0.0457 - accuracy: 1.0000 - val_loss: 1.0721 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.0770 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 0.0419 - accuracy: 1.0000 - val_loss: 1.0776 - val_accuracy: 0.7000 - 24ms/epoch - 974us/step
# Epoch 40/100
# 25/25 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.0813 - val_accuracy: 0.7000 - 43ms/epoch - 2ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.0808 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.0882 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 0.0355 - accuracy: 1.0000 - val_loss: 1.0851 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.0885 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 0.0329 - accuracy: 1.0000 - val_loss: 1.0865 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 1.0951 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 0.0305 - accuracy: 1.0000 - val_loss: 1.0946 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 1.0964 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.1005 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.0984 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.1058 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 0.0256 - accuracy: 1.0000 - val_loss: 1.1057 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.1069 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 1.1116 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 1.1120 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.1169 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 1.1205 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.1237 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.1237 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.1271 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.1280 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 1.1315 - val_accuracy: 0.7000 - 35ms/epoch - 1ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.1364 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 1.1363 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.1412 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.1407 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 1.1453 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.1450 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.1499 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.1530 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.1545 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.1558 - val_accuracy: 0.7000 - 31ms/epoch - 1ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.1594 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.1583 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.1631 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.1614 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.1687 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.1700 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.1726 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 83/100
# 25/25 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.1709 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.1745 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.1757 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.1783 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.1762 - val_accuracy: 0.7000 - 34ms/epoch - 1ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.1790 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.1824 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.1882 - val_accuracy: 0.7000 - 31ms/epoch - 1ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1859 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.1884 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.1899 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1918 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.1941 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.1985 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1972 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1966 - val_accuracy: 0.7000 - 32ms/epoch - 1ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.2002 - val_accuracy: 0.7000 - 37ms/epoch - 1ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.2021 - val_accuracy: 0.7000 - 33ms/epoch - 1ms/step

# %% [markdown]
# Results
# =======
#
# We can finally plot the test accuracy and the test loss with respect to
# the number of training epochs.

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(9, 12))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\monitsharma\AppData\Local\Temp\ipykernel_33376\3607704385.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# References
# ==========
#
# 1.  Maxwell Henderson, Samriddhi Shakya, Shashindra Pradhan, Tristan
#     Cook. \"Quanvolutional Neural Networks: Powering Image Recognition
#     with Quantum Circuits.\"
#     [arXiv:1904.04767](https://arxiv.org/abs/1904.04767), 2019.
